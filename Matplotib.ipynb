# %%
import pandas as pd
df = pd.read_csv("C:\\Users\\Harsha\\Desktop\\Pandas\\Employee.csv")
df.head()
# Out:
#     id FIRST_NAME LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  SALARY  \
# 0  100     Steven      King     SKING  515.123.4567  6/17/1987   24000
# 1  101      Neena   Kochhar  NKOCHHAR  515.123.4568  9/21/1989   17000
# 2  102        Lex   De Haan   LDEHAAN  515.123.4569  1/13/1993   17000
# 3  103  Alexander    Hunold   AHUNOLD  590.423.4567   1/3/1990    9000
# 4  105      David    Austin   DAUSTIN  590.423.4569  6/25/1997    4800
#
#    DEPARTMENT_ID
# 0             90
# 1             90
# 2             90
# 3             60
# 4             60

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\\Harsha\\Desktop\\Pandas\\Employee.csv") 
plt.plot(df['FIRST_NAME'], df['SALARY'])

plt.xlabel('FIRST_NAME')           
plt.ylabel('SALARY')      
plt.title('emp')             
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\\Harsha\\Desktop\\Pandas\\Employee.csv") 
plt.plot(df['FIRST_NAME'], df['SALARY'],'ro')

plt.xlabel('FIRST_NAME')           
plt.ylabel('SALARY')      
plt.title('emp')             
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\\Harsha\\Desktop\\Pandas\\Employee.csv") 
plt.plot(df['HIRE_DATE'], df['SALARY'], color='red', linestyle=':', linewidth = 2, marker='h', markerfacecolor='black', markersize=7)

plt.xlabel('HIRE_DATE')           
plt.ylabel('SALARY')      
plt.title('emp')             
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\\Harsha\\Desktop\\Pandas\\Employee.csv") 
plt.plot(df['HIRE_DATE'], df['SALARY'])

plt.xlabel('HIRE_DATE')           
plt.ylabel('SALARY')      
plt.title('emp')  
plt.scatter(df['HIRE_DATE'], df['SALARY'])
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\\Harsha\\Desktop\\Pandas\\Employee.csv") 
plt.plot(df['HIRE_DATE'], df['SALARY'],'ro', label= "", color="orange", marker="^")
plt.xlabel('HIRE_DATE')           
plt.ylabel('SALARY')      
plt.title('emp')  
plt.legend() 
plt.show()
# Out:
# C:\Users\Harsha\AppData\Local\Temp\ipykernel_1460\673289924.py:4: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "ro" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot(df['HIRE_DATE'], df['SALARY'],'ro', label= "", color="orange", marker="^")
# C:\Users\Harsha\AppData\Local\Temp\ipykernel_1460\673289924.py:4: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "ro" (-> color='r'). The keyword argument will take precedence.
#   plt.plot(df['HIRE_DATE'], df['SALARY'],'ro', label= "", color="orange", marker="^")
# C:\Users\Harsha\AppData\Local\Temp\ipykernel_1460\673289924.py:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
y=np.array([45,10,25,15,5])
plt.pie(y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
y=np.array([45,25,15,15])
mylabels = ["Diet", "Workout", "Rest", "MakingMoney"]
mycolors = ["b", "r", "black", "y"]
plt.title('Body Recomposition')
plt.pie(y, labels = mylabels, startangle = 90,colors=mycolors)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("C:\\Users\\Harsha\\Desktop\\Pandas\\Employee.csv") 
plt.plot(df['HIRE_DATE'], df['SALARY'])
plt.xlabel('HIRE_DATE')           
plt.ylabel('SALARY')      
plt.title('emp')  
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([45,10,25,15,5])
y=np.array([10,20,30,40,50])
plt.title("GYM")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y)
plt.grid(axis='x')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([45,10,25,15,5])
y=np.array([10,20,30,40,50])
plt.title("GYM")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y)
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
y=np.array([45,10,25,15,5])
x=np.array([10,20,30,40,50])
plt.title("GYM")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.plot(x,y)
plt.grid(color = 'y', linestyle = '-.', linewidth = 0.7)
plt.show()
