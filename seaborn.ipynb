# %%
import seaborn as sns
titanic=sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic.info
# Out:
# <bound method DataFrame.info of      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
import seaborn as sns
tips=sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import seaborn as sns
dots=sns.load_dataset('dots')
dots
# Out:
#     align choice  time  coherence  firing_rate
# 0    dots     T1   -80        0.0    33.189967
# 1    dots     T1   -80        3.2    31.691726
# 2    dots     T1   -80        6.4    34.279840
# 3    dots     T1   -80       12.8    32.631874
# 4    dots     T1   -80       25.6    35.060487
# ..    ...    ...   ...        ...          ...
# 843  sacc     T2   300        3.2    33.281734
# 844  sacc     T2   300        6.4    27.583979
# 845  sacc     T2   300       12.8    28.511530
# 846  sacc     T2   300       25.6    27.009804
# 847  sacc     T2   300       51.2    30.959302
#
# [848 rows x 5 columns]

# %%
dots.shape
# Out:
# (848, 5)

# %%
titanic.shape
# Out:
# (891, 15)

# %%
tips.shape
# Out:
# (244, 7)

# %%
sns.histplot(data=titanic, x='class', bins=25, kde=True, color='Red')
# Out:
# <Axes: xlabel='class', ylabel='Count'>

# %%
sns.histplot(data=tips, x='sex', bins=1, kde=True, color='skyblue')
# Out:
# <Axes: xlabel='sex', ylabel='Count'>

# %%
exercise=sns.load_dataset('exercise')
exercise
# Out:
#     Unnamed: 0  id     diet  pulse    time     kind
# 0            0   1  low fat     85   1 min     rest
# 1            1   1  low fat     85  15 min     rest
# 2            2   1  low fat     88  30 min     rest
# 3            3   2  low fat     90   1 min     rest
# 4            4   2  low fat     92  15 min     rest
# ..         ...  ..      ...    ...     ...      ...
# 85          85  29   no fat    135  15 min  running
# 86          86  29   no fat    130  30 min  running
# 87          87  30   no fat     99   1 min  running
# 88          88  30   no fat    111  15 min  running
# 89          89  30   no fat    150  30 min  running
#
# [90 rows x 6 columns]

# %%
sns.histplot(data=exercise, x='pulse')
# Out:
# <Axes: xlabel='pulse', ylabel='Count'>

# %%
sns.scatterplot(data=exercise, x='pulse', y='kind', color='green')
# Out:
# <Axes: xlabel='pulse', ylabel='kind'>

# %%
sns.lineplot(data=titanic, x='embarked', y='fare', marker='p', color='blue')
# Out:
# <Axes: xlabel='embarked', ylabel='fare'>

# %%
sns.barplot(data=tips, x='total_bill', y='tip', palette='pastel',width=1.5)
# Out:
# C:\Users\Harsha\AppData\Local\Temp\ipykernel_1320\4248270345.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tips, x='total_bill', y='tip', palette='pastel',width=1.5)
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.countplot(data=exercise, x='diet', palette='pastel',width=0.2)
# Out:
# C:\Users\Harsha\AppData\Local\Temp\ipykernel_1320\2936588484.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=exercise, x='diet', palette='pastel',width=0.2)
# <Axes: xlabel='diet', ylabel='count'>

# %%
sns.violinplot(data=titanic, x='who', y='class', palette='Set3')
# Out:
# C:\Users\Harsha\AppData\Local\Temp\ipykernel_1320\4148648556.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=titanic, x='who', y='class', palette='Set3')
# <Axes: xlabel='who', ylabel='class'>

# %%
sns.pairplot(titanic)

# %%
sns.boxplot(data=tips, x='sex', y='tip', palette='Set2')
# Out:
# C:\Users\Harsha\AppData\Local\Temp\ipykernel_1320\3612715476.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=tips, x='sex', y='tip', palette='Set2')
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.catplot(data=exercise, x='pulse', y='kind', kind='bar', palette='pastel', height=3, aspect=1.7)
# Out:
# C:\Users\Harsha\AppData\Local\Temp\ipykernel_1320\1899654704.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=exercise, x='pulse', y='kind', kind='bar', palette='pastel', height=3, aspect=1.7)
